# %% [markdown]
# # 1 teste

# %%
import pandas as pd
import numpy as np

file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_data = excel_data.parse('Forecast')


# Converter 'Forecast' para numérico, lidando com valores ausentes
forecast_data['Forecast'] = pd.to_numeric(forecast_data['Forecast'], errors='coerce').fillna(0)

# Filtrar apenas dados com pelo menos uma saída
filtered_data = forecast_data[forecast_data['Saidas'] > 0]

# Função para calcular a acurácia direta
def calculate_accuracy_percentage(group):
    actual = group['Saidas']
    forecast = group['Forecast']
    mape = (np.abs(actual - forecast) / actual).mean() * 100
    accuracy_percentage = 100 - mape
    return pd.Series({'Accuracy (%)': accuracy_percentage})


channel_accuracy_direct = filtered_data.groupby('Canal').apply(calculate_direct_accuracy_percentage).reset_index()
material_accuracy_direct = filtered_data.groupby('Material').apply(calculate_direct_accuracy_percentage).reset_index()
model_accuracy_direct = filtered_data.groupby('Model(Rep)').apply(calculate_direct_accuracy_percentage).reset_index()
date_accuracy_direct = filtered_data.groupby('Data FCST').apply(calculate_direct_accuracy_percentage).reset_index()

# %%
channel_accuracy_direct

# %%
material_accuracy_direct

# %%
model_accuracy_direct

# %%
date_accuracy_direct

# %% [markdown]
# # 2 teste

# %%
import pandas as pd
import numpy as np

# Carregar o arquivo Excel e a planilha "Forecast"
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_data = excel_data.parse('Forecast')

# Converter a coluna 'Forecast' para numérico, lidando com valores ausentes
forecast_data['Forecast'] = pd.to_numeric(forecast_data['Forecast'], errors='coerce').fillna(0)

# Filtrar os dados para incluir apenas registros onde há pelo menos uma saída
filtered_data = forecast_data[forecast_data['Saidas'] > 0]

# Função para calcular a acurácia, total de Forecast e total de Saídas
def calculate_accuracy_percentage(group):
    actual = group['Saidas']
    forecast = group['Forecast']
    mape = (np.abs(actual - forecast) / actual).mean() * 100
    accuracy_percentage = 100 - mape
    return pd.Series({'Accuracy (%)': accuracy_percentage})
# Calcular a acurácia, total Forecast e total Saídas para cada grupo
channel_accuracy_direct = filtered_data.groupby('Canal').apply(calculate_accuracy_percentage).reset_index()
material_accuracy_direct = filtered_data.groupby('Material').apply(calculate_accuracy_percentage).reset_index()
model_accuracy_direct = filtered_data.groupby('Model(Rep)').apply(calculate_accuracy_percentage).reset_index()
date_accuracy_direct = filtered_data.groupby('Data FCST').apply(calculate_accuracy_percentage).reset_index()

# Exibir resultados
channel_accuracy_direct

# %%
material_accuracy_direct

# %%
model_accuracy_direct

# %%
date_accuracy_direct

# %% [markdown]
# # 3 Teste -  sMAPE

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')


# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrando apenas os itens com 'Saidas' > 0
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o sMAPE para cada linha
forecast_df_filtered['sMAPE'] = (
    abs(forecast_df_filtered['Forecast'] - forecast_df_filtered['Saidas']) / 
    ((abs(forecast_df_filtered['Saidas']) + abs(forecast_df_filtered['Forecast'])) / 2)
) * 100

# Calculando a média de sMAPE por 'Canal'
smape_by_canal = forecast_df_filtered.groupby('Canal')['sMAPE'].mean().reset_index()

# Exibindo o resultado
print(smape_by_canal)

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\FCST X RESULT\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrando apenas os itens com 'Saidas' > 0
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o sMAPE para cada linha
forecast_df_filtered['sMAPE'] = (
    abs(forecast_df_filtered['Forecast'] - forecast_df_filtered['Saidas']) / 
    ((abs(forecast_df_filtered['Saidas']) + abs(forecast_df_filtered['Forecast'])) / 2)
) * 100

# Calculando a média de sMAPE por 'Material'
smape_by_material = forecast_df_filtered.groupby('Material')['sMAPE'].mean().reset_index()

# Exibindo o resultado
print(smape_by_material)

# %% [markdown]
# # 4 teste - MAE

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')
# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrando apenas os itens com 'Saidas' > 0
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o MAE para cada linha
forecast_df_filtered['MAE'] = abs(forecast_df_filtered['Forecast'] - forecast_df_filtered['Saidas'])

# Calculando a média do MAE por 'Material'
mae_by_material = forecast_df_filtered.groupby('Material')['MAE'].mean().reset_index()

# Exibindo o resultado
print(mae_by_material)

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrando apenas os itens com 'Saidas' > 0
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o MAE para cada linha
forecast_df_filtered['MAE'] = abs(forecast_df_filtered['Forecast'] - forecast_df_filtered['Saidas'])

# Calculando a média do MAE por 'Canal'
mae_by_canal = forecast_df_filtered.groupby('Canal')['MAE'].mean().reset_index()

# Exibindo o resultado
print(mae_by_canal)

# %% [markdown]
# # 5 teste BIAS

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

# %%
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrando apenas os itens com 'Saidas' > 0
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o Forecast Bias para cada linha
forecast_df_filtered['Forecast Bias'] = forecast_df_filtered['Forecast'] - forecast_df_filtered['Saidas']

# Calculando o Forecast Bias médio por 'Canal'
forecast_bias_by_canal = forecast_df_filtered.groupby('Canal')['Forecast Bias'].mean().reset_index()

# Exibindo o resultado
print(forecast_bias_by_canal)

# %% [markdown]
# # 6 Teste - ME

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data Referencia' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data Referencia'] = pd.to_datetime(forecast_df['Data Referencia'], errors='coerce')

# Filtrando para o canal 'Indireto SP'
indireto_sp_df = forecast_df[forecast_df['Canal'] == 'Indireto SP']

# Agrupando por mês para somar os valores de 'Forecast' e 'Saidas'
monthly_totals = indireto_sp_df.groupby(indireto_sp_df['Data Referencia'].dt.to_period("M"))[['Forecast', 'Saidas']].sum()

# Calculando o erro médio absoluto entre Forecast e Saidas
average_error = abs(monthly_totals['Forecast'] - monthly_totals['Saidas']).mean()

# Calculando o erro médio em porcentagem com base na média de Saidas
average_saidas = monthly_totals['Saidas'].mean()
percentage_error = (average_error / average_saidas) * 100

# Exibindo os resultados
print("Erro Médio Absoluto:", average_error)
print("Erro Médio em Percentual:", percentage_error, "%")

# %%
# Convertendo as colunas para numérico e 'Data Referencia' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data Referencia'] = pd.to_datetime(forecast_df['Data Referencia'], errors='coerce')

# Função para calcular erro médio absoluto e percentual
def calculate_errors(group):
    monthly_totals = group.groupby(group['Data Referencia'].dt.to_period("M"))[['Forecast', 'Saidas']].sum()
    average_error = abs(monthly_totals['Forecast'] - monthly_totals['Saidas']).mean()
    average_saidas = monthly_totals['Saidas'].mean()
    percentage_error = (average_error / average_saidas) * 100
    return pd.Series({'Erro Médio Absoluto': average_error, 'Erro Médio Percentual': percentage_error})

# Calculando erros por Canal
errors_by_canal = forecast_df.groupby('Canal').apply(calculate_errors).reset_index()

# Calculando erros por Material
errors_by_material = forecast_df.groupby('Material').apply(calculate_errors).reset_index()

# Exibindo os resultados
print("Erros por Canal:")
print(errors_by_canal)

print("\nErros por Material:")
print(errors_by_material)

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data FCST' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrando para valores de 'Saidas' maiores que zero
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Função para calcular erro médio absoluto, percentual e acurácia por Canal
def calculate_errors_by_canal(group):
    # Agrupando os dados por ano e mês
    monthly_totals = group.groupby(group['Data FCST'].dt.to_period("M"))[['Forecast', 'Saidas']].sum()
    
    # Calculando os erros absolutos e percentuais para cada mês
    monthly_totals['Erro Médio Absoluto'] = abs(monthly_totals['Forecast'] - monthly_totals['Saidas'])
    monthly_totals['Erro Médio Percentual'] = (monthly_totals['Erro Médio Absoluto'] / monthly_totals['Saidas']) * 100
    
    # Calculando a Acurácia como 100% - Erro Médio Percentual
    monthly_totals['Acurácia (%)'] = 100 - monthly_totals['Erro Médio Percentual']
    
    # Resetando o índice para que 'Data FCST' seja uma coluna e não o índice do DataFrame
    monthly_totals = monthly_totals.reset_index()
    monthly_totals['Data FCST'] = monthly_totals['Data FCST'].dt.strftime('%m/%Y')  # Formata para 'mês/ano'
    
    # Selecionando apenas as colunas desejadas
    return monthly_totals[['Data FCST', 'Erro Médio Absoluto', 'Erro Médio Percentual', 'Acurácia (%)']]

# Aplicando a função por Canal e mantendo o índice de canal
errors_by_canal = forecast_df_filtered.groupby('Canal').apply(calculate_errors_by_canal).reset_index()

# Exibindo os resultados por Canal
print("Erros por Canal:")
print(errors_by_canal)

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data FCST' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrando para valores de 'Saidas' maiores que zero
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Agrupando por canal e somando Forecast e Saidas
totals_by_canal = forecast_df_filtered.groupby('Canal')[['Forecast', 'Saidas']].sum().reset_index()

# Calculando o Erro Médio Absoluto, Erro Médio Percentual e Acurácia para cada canal
totals_by_canal['Erro Médio Absoluto'] = abs(totals_by_canal['Forecast'] - totals_by_canal['Saidas'])
totals_by_canal['Erro Médio Percentual'] = (totals_by_canal['Erro Médio Absoluto'] / totals_by_canal['Saidas']) * 100
totals_by_canal['Acurácia (%)'] = 100 - totals_by_canal['Erro Médio Percentual']

# Exibindo os resultados consolidados por canal
print("Erros Consolidados por Canal:")
print(totals_by_canal[['Canal', 'Erro Médio Absoluto', 'Erro Médio Percentual', 'Acurácia (%)']])

# %% [markdown]
# # mse e rmse

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data FCST' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrando para valores de 'Saidas' maiores que zero
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o Erro Quadrático Médio (MSE) e o RMSE para cada canal
def calculate_mse_rmse(group):
    # Calculando o erro quadrático para cada linha
    group['Erro Quadrático'] = (group['Forecast'] - group['Saidas']) ** 2
    # Calculando o MSE (média do erro quadrático)
    mse = group['Erro Quadrático'].mean()
    # Calculando o RMSE como a raiz quadrada do MSE
    rmse = mse ** 0.5
    return pd.Series({'MSE': mse, 'RMSE': rmse})

# Aplicando a função por Canal
mse_rmse_by_canal = forecast_df_filtered.groupby('Canal').apply(calculate_mse_rmse).reset_index()

# Exibindo os resultados de MSE e RMSE por Canal
print("MSE e RMSE por Canal:")
print(mse_rmse_by_canal)

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data FCST' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrando para valores de 'Saidas' maiores que zero
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando o MSE e RMSE, e transformando o RMSE em uma média percentual
def calculate_mse_rmse_percent(group):
    # Calculando o erro quadrático para cada linha
    group['Erro Quadrático'] = (group['Forecast'] - group['Saidas']) ** 2
    # Calculando o MSE (média do erro quadrático)
    mse = group['Erro Quadrático'].mean()
    # Calculando o RMSE como a raiz quadrada do MSE
    rmse = mse ** 0.5
    # Calculando a média de Saidas para o canal
    media_saidas = group['Saidas'].mean()
    # Transformando o RMSE em percentual em relação à média de Saidas
    rmse_percent = (rmse / media_saidas) * 100
    return pd.Series({'MSE': mse, 'RMSE': rmse, 'RMSE (%)': rmse_percent})

# Aplicando a função por Canal
mse_rmse_percent_by_canal = forecast_df_filtered.groupby('Canal').apply(calculate_mse_rmse_percent).reset_index()

# Exibindo os resultados
print("MSE, RMSE e RMSE (%) por Canal:")
print(mse_rmse_percent_by_canal)

# %%
import pandas as pd

# Supondo que forecast_df seja o seu DataFrame inicial com as colunas 'Forecast', 'Saidas', 'Canal', etc.

# Convertendo as colunas para numérico e 'Data FCST' para datetime
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrando para valores de 'Saidas' maiores que zero
forecast_df_filtered = forecast_df[forecast_df['Saidas'] > 0].copy()

# Calculando a média total de Saidas considerando todos os canais
media_saidas_total = forecast_df_filtered['Saidas'].mean()

# Função para calcular MSE, RMSE e RMSE (%) em relação à média total de Saidas
def calculate_mse_rmse_percent(group):
    # Calculando o erro quadrático para cada linha
    group['Erro Quadrático'] = (group['Forecast'] - group['Saidas']) ** 2
    # Calculando o MSE (média do erro quadrático)
    mse = group['Erro Quadrático'].mean()
    # Calculando o RMSE como a raiz quadrada do MSE
    rmse = mse ** 0.5
    # Transformando o RMSE em percentual em relação à média total de Saidas
    rmse_percent = (rmse / media_saidas_total) * 100
    return pd.Series({'MSE': mse, 'RMSE': rmse, 'RMSE (%)': rmse_percent})

# Aplicando a função por Canal
mse_rmse_percent_by_canal = forecast_df_filtered.groupby('Canal').apply(calculate_mse_rmse_percent).reset_index()

# Exibindo os resultados sem limite de 100% no RMSE (%)
print("MSE, RMSE e RMSE (%) por Canal (usando média total de Saidas):")
print(mse_rmse_percent_by_canal)

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\FCST X RESULT\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')


# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')

# Filtrar para incluir apenas os valores onde 'Saidas' > 0
forecast_df_filtered_positive = forecast_df[forecast_df['Saidas'] > 0].copy()

# Função para calcular a acuracidade com base nas somas totais de Forecast e Saidas para cada grupo
def calculate_acuracidade_total(group):
    total_forecast = group['Forecast'].sum()
    total_saidas = group['Saidas'].sum()
    # Calcular a acuracidade com as somas totais
    acuracidade_total = 100 - (abs(total_forecast - total_saidas) / total_saidas) * 100
    return acuracidade_total

# Aplicar a função de cálculo por canal
acuracidade_by_canal_total_positive = forecast_df_filtered_positive.groupby('Canal').apply(calculate_acuracidade_total).reset_index(name='Acuracidade Média Total')

# Aplicar a função de cálculo por material
acuracidade_by_material_total_positive = forecast_df_filtered_positive.groupby('Material').apply(calculate_acuracidade_total).reset_index(name='Acuracidade Média Total')

# Caminho para salvar o arquivo Excel
output_file_path = 'Acuracidade_Resultados.xlsx'

# Salvando os resultados em um arquivo Excel com duas abas
with pd.ExcelWriter(output_file_path) as writer:
    acuracidade_by_canal_total_positive.to_excel(writer, sheet_name='Acuracidade por Canal', index=False)
    acuracidade_by_material_total_positive.to_excel(writer, sheet_name='Acuracidade por Material', index=False)

print(f"Arquivo Excel salvo em: {output_file_path}")

# %% [markdown]
# # Erro Relativo Normalizado e Acuracidade

# %% [markdown]
# ## Total saidas

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrar para incluir apenas os valores onde 'Saidas' > 0
forecast_df_filtered_positive = forecast_df[forecast_df['Saidas'] > 0].copy()

# Adicionar coluna de mês para cálculos mensais
forecast_df_filtered_positive['Mes'] = forecast_df_filtered_positive['Data FCST'].dt.to_period("M")

# Função para calcular o Erro Relativo Normalizado
def calculate_erro_relativo_normalizado(group):
    total_forecast = group['Forecast'].sum()
    total_saidas = group['Saidas'].sum()
    if total_saidas != 0:
        erro_relativo_normalizado = abs(total_forecast - total_saidas) / total_saidas
    else:
        erro_relativo_normalizado = None  # Evita divisão por zero
    return erro_relativo_normalizado

# 1. Erro Relativo Normalizado e Acuracidade por Mês e Canal
erro_relativo_by_month_canal = forecast_df_filtered_positive.groupby(['Canal', 'Mes']).apply(calculate_erro_relativo_normalizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_canal['Acuracidade'] = 100 - (erro_relativo_by_month_canal['Erro Relativo Normalizado'] * 100)

# 2. Média de Erro Relativo Normalizado e Acuracidade por Canal
erro_relativo_media_canal = erro_relativo_by_month_canal.groupby('Canal')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_canal['Acuracidade Média'] = 100 - (erro_relativo_media_canal['Erro Relativo Normalizado Médio'] * 100)

# 3. Erro Relativo Normalizado e Acuracidade por Mês e Material
erro_relativo_by_month_material = forecast_df_filtered_positive.groupby(['Material', 'Mes']).apply(calculate_erro_relativo_normalizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_material['Acuracidade'] = 100 - (erro_relativo_by_month_material['Erro Relativo Normalizado'] * 100)

# 4. Média de Erro Relativo Normalizado e Acuracidade por Material
erro_relativo_media_material = erro_relativo_by_month_material.groupby('Material')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_material['Acuracidade Média'] = 100 - (erro_relativo_media_material['Erro Relativo Normalizado Médio'] * 100)

# Salvando os resultados em um arquivo Excel com todas as abas
output_file_path = 'Erro_Relativo_Normalizado_Acuracidade.xlsx'

with pd.ExcelWriter(output_file_path) as writer:
    erro_relativo_by_month_canal.to_excel(writer, sheet_name='Erro Relativo Mensal', index=False)
    erro_relativo_media_canal.to_excel(writer, sheet_name='Erro Relativo Média por Canal', index=False)
    erro_relativo_by_month_material.to_excel(writer, sheet_name='Erro Relativo por Material', index=False)
    erro_relativo_media_material.to_excel(writer, sheet_name='Erro Relativo Média Material', index=False)

print(f"Arquivo Excel salvo em: {output_file_path}")

# %% [markdown]
# ## Media de saidas

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrar para incluir apenas os valores onde 'Saidas' > 0
forecast_df_filtered_positive = forecast_df[forecast_df['Saidas'] > 0].copy()

# Adicionar coluna de mês para cálculos mensais
forecast_df_filtered_positive['Mes'] = forecast_df_filtered_positive['Data FCST'].dt.to_period("M")

def calculate_erro_relativo_normalizado(group):
    total_forecast = group['Forecast'].sum()
    media_saidas = group['Saidas'].mean()  # Usando a média das saídas para normalização
    if media_saidas != 0:
        erro_relativo_normalizado = abs(total_forecast - group['Saidas'].sum()) / media_saidas
    else:
        erro_relativo_normalizado = None  # Evita divisão por zero
    return erro_relativo_normalizado


# 1. Erro Relativo Normalizado e Acuracidade por Mês e Canal
erro_relativo_by_month_canal = forecast_df_filtered_positive.groupby(['Canal', 'Mes']).apply(calculate_erro_relativo_normalizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_canal['Acuracidade'] = 100 - (erro_relativo_by_month_canal['Erro Relativo Normalizado'] * 100)

# 2. Média de Erro Relativo Normalizado e Acuracidade por Canal
erro_relativo_media_canal = erro_relativo_by_month_canal.groupby('Canal')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_canal['Acuracidade Média'] = 100 - (erro_relativo_media_canal['Erro Relativo Normalizado Médio'] * 100)

# 3. Erro Relativo Normalizado e Acuracidade por Mês e Material
erro_relativo_by_month_material = forecast_df_filtered_positive.groupby(['Material', 'Mes']).apply(calculate_erro_relativo_normalizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_material['Acuracidade'] = 100 - (erro_relativo_by_month_material['Erro Relativo Normalizado'] * 100)

# 4. Média de Erro Relativo Normalizado e Acuracidade por Material
erro_relativo_media_material = erro_relativo_by_month_material.groupby('Material')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_material['Acuracidade Média'] = 100 - (erro_relativo_media_material['Erro Relativo Normalizado Médio'] * 100)

# Salvando os resultados em um arquivo Excel com todas as abas
output_file_path = 'Erro_Relativo_Normalizado_Acuracidade2.xlsx'

with pd.ExcelWriter(output_file_path) as writer:
    erro_relativo_by_month_canal.to_excel(writer, sheet_name='Erro Relativo Mensal', index=False)
    erro_relativo_media_canal.to_excel(writer, sheet_name='Erro Relativo Média por Canal', index=False)
    erro_relativo_by_month_material.to_excel(writer, sheet_name='Erro Relativo por Material', index=False)
    erro_relativo_media_material.to_excel(writer, sheet_name='Erro Relativo Média Material', index=False)

print(f"Arquivo Excel salvo em: {output_file_path}")

# %%
def calculate_erro_relativo_normalizado_suavizado(group, suavizacao=1):
    total_forecast = group['Forecast'].sum()
    media_saidas = group['Saidas'].mean() + suavizacao  # Adiciona suavização ao denominador
    if media_saidas != 0:
        erro_relativo_normalizado = abs(total_forecast - group['Saidas'].sum()) / media_saidas
    else:
        erro_relativo_normalizado = None  # Evita divisão por zero
    return erro_relativo_normalizado

# %%
file_path = r'C:\Users\fsp_adolpho.salvador\Desktop\Konica Minolta\Desktop Cloud - Documentos\Desktop\Py\Projeto Resultados\Forecast\Arquivos\Forecast.xlsx'
excel_data = pd.ExcelFile(file_path)
forecast_df = excel_data.parse('Forecast')

# Convertendo as colunas 'Forecast' e 'Saidas' para numérico, ignorando erros
forecast_df['Forecast'] = pd.to_numeric(forecast_df['Forecast'], errors='coerce')
forecast_df['Saidas'] = pd.to_numeric(forecast_df['Saidas'], errors='coerce')
forecast_df['Data FCST'] = pd.to_datetime(forecast_df['Data FCST'], errors='coerce')

# Filtrar para incluir apenas os valores onde 'Saidas' > 0
forecast_df_filtered_positive = forecast_df[forecast_df['Saidas'] > 0].copy()

# Adicionar coluna de mês para cálculos mensais
forecast_df_filtered_positive['Mes'] = forecast_df_filtered_positive['Data FCST'].dt.to_period("M")

def calculate_erro_relativo_normalizado_suavizado(group, suavizacao=1):
    total_forecast = group['Forecast'].sum()
    media_saidas = group['Saidas'].mean() + suavizacao  # Adiciona suavização ao denominador
    if media_saidas != 0:
        erro_relativo_normalizado = abs(total_forecast - group['Saidas'].sum()) / media_saidas
    else:
        erro_relativo_normalizado = None  # Evita divisão por zero
    return erro_relativo_normalizado



# 1. Erro Relativo Normalizado e Acuracidade por Mês e Canal
erro_relativo_by_month_canal = forecast_df_filtered_positive.groupby(['Canal', 'Mes']).apply(calculate_erro_relativo_normalizado_suavizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_canal['Acuracidade'] = 100 - (erro_relativo_by_month_canal['Erro Relativo Normalizado'] * 100)

# 2. Média de Erro Relativo Normalizado e Acuracidade por Canal
erro_relativo_media_canal = erro_relativo_by_month_canal.groupby('Canal')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_canal['Acuracidade Média'] = 100 - (erro_relativo_media_canal['Erro Relativo Normalizado Médio'] * 100)

# 3. Erro Relativo Normalizado e Acuracidade por Mês e Material
erro_relativo_by_month_material = forecast_df_filtered_positive.groupby(['Material', 'Mes']).apply(calculate_erro_relativo_normalizado_suavizado).reset_index(name='Erro Relativo Normalizado')
erro_relativo_by_month_material['Acuracidade'] = 100 - (erro_relativo_by_month_material['Erro Relativo Normalizado'] * 100)

# 4. Média de Erro Relativo Normalizado e Acuracidade por Material
erro_relativo_media_material = erro_relativo_by_month_material.groupby('Material')['Erro Relativo Normalizado'].mean().reset_index(name='Erro Relativo Normalizado Médio')
erro_relativo_media_material['Acuracidade Média'] = 100 - (erro_relativo_media_material['Erro Relativo Normalizado Médio'] * 100)

# Salvando os resultados em um arquivo Excel com todas as abas
output_file_path = 'Erro_Relativo_Normalizado_Acuracidade3.xlsx'

with pd.ExcelWriter(output_file_path) as writer:
    erro_relativo_by_month_canal.to_excel(writer, sheet_name='Erro Relativo Mensal', index=False)
    erro_relativo_media_canal.to_excel(writer, sheet_name='Erro Relativo Média por Canal', index=False)
    erro_relativo_by_month_material.to_excel(writer, sheet_name='Erro Relativo por Material', index=False)
    erro_relativo_media_material.to_excel(writer, sheet_name='Erro Relativo Média Material', index=False)

print(f"Arquivo Excel salvo em: {output_file_path}")
